# %% [markdown]
# # Governed Market Memory MCP — Five-Minute Classroom Laboratory
#
# **Purpose.** Reconstruct the complete workflow transparently: configuration → provider → governance gates → predecessor memory → five reports → final narrative → cryptographic audit bundle → MCP exposure.
#
# The default observations are **SIMULATED**. The notebook never describes them as live Yahoo Finance quotations.

# %% [markdown]
# ## Learning objectives
#
# By the end, students can explain why MCP supplies controlled capabilities but not a clock; why an orchestrator schedules cycles; how an Obsidian vault supplies cumulative memory; and why transparency must be strengthened into auditability and authorization.

# %%
# Colab setup: mount Drive only when running in Google Colab.
try:
    from google.colab import drive
    drive.mount('/content/drive')
    IN_COLAB = True
except ImportError:
    IN_COLAB = False
print({'in_colab': IN_COLAB})
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# {'in_colab': True}

# %%
# Choose the working directory. Change DRIVE_FOLDER to your mounted folder when needed.
from pathlib import Path
DRIVE_FOLDER = Path('/content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER') if IN_COLAB else Path.cwd()
PACKAGE_ROOT = DRIVE_FOLDER / 'Governed_Market_Memory_MCP_Classroom'
VAULT = PACKAGE_ROOT / 'Market_Day_Obsidian_Vault'
PACKAGE_ROOT.mkdir(parents=True, exist_ok=True)
print({'package_root': str(PACKAGE_ROOT), 'vault': str(VAULT)})
# Out:
# {'package_root': '/content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom', 'vault': '/content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom/Market_Day_Obsidian_Vault'}

# %% [markdown]
# ## Architecture
#
# The provider observes. The governance engine decides admissibility. The vault persists memory. The orchestrator supplies the clock. The MCP server exposes bounded tools. A model may interpret accepted evidence but may not override failed gates.

# %%
# ============================================================
# COLAB BOOTSTRAP — LOCATE AND LOAD market_mcp
# ============================================================

from google.colab import drive
drive.mount("/content/drive", force_remount=False)

from pathlib import Path
import sys
import subprocess
import importlib
import zipfile

DRIVE_FOLDER = Path(
    "/content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/"
    "THE FINANCIAL REPORTER"
)

PACKAGE_NAME = "Governed_Market_Memory_MCP_Classroom"
EXPECTED_ROOT = DRIVE_FOLDER / PACKAGE_NAME

print("Searching under:", DRIVE_FOLDER)

if not DRIVE_FOLDER.exists():
    raise FileNotFoundError(
        f"Google Drive directory not found:\n{DRIVE_FOLDER}\n"
        "Check every folder name, including spaces."
    )

# ------------------------------------------------------------
# 1. Extract ZIP if the package has not yet been extracted
# ------------------------------------------------------------

zip_candidates = list(DRIVE_FOLDER.rglob("*.zip"))

if zip_candidates:
    print("\nZIP files detected:")
    for z in zip_candidates:
        print(" -", z)

    if not EXPECTED_ROOT.exists():
        EXPECTED_ROOT.mkdir(parents=True, exist_ok=True)

    for zip_path in zip_candidates:
        print(f"Inspecting/extracting: {zip_path.name}")
        with zipfile.ZipFile(zip_path, "r") as archive:
            archive.extractall(EXPECTED_ROOT)

# ------------------------------------------------------------
# 2. Find the actual Python package using its required files
# ------------------------------------------------------------

package_candidates = []

for path in DRIVE_FOLDER.rglob("market_mcp"):
    if (
        path.is_dir()
        and (path / "__init__.py").exists()
        and (path / "core.py").exists()
        and (path / "orchestrator.py").exists()
    ):
        package_candidates.append(path)

if not package_candidates:
    print("\nNearby files found:")
    for path in list(DRIVE_FOLDER.rglob("*"))[:100]:
        print(" -", path)

    raise FileNotFoundError(
        "\nA complete market_mcp package was not found.\n\n"
        "Required structure:\n"
        "Governed_Market_Memory_MCP_Classroom/\n"
        "├── market_mcp/\n"
        "│   ├── __init__.py\n"
        "│   ├── core.py\n"
        "│   └── orchestrator.py\n"
        "└── pyproject.toml\n\n"
        "Make sure the COMPLETE package ZIP—not only the notebook—"
        "is stored and extracted in the Drive folder."
    )

PACKAGE_DIR = package_candidates[0]
PACKAGE_ROOT = PACKAGE_DIR.parent

print("\n✅ Python package found")
print("Package directory:", PACKAGE_DIR)
print("Package root:", PACKAGE_ROOT)

# ------------------------------------------------------------
# 3. Make the module immediately importable
# ------------------------------------------------------------

# This direct path insertion is decisive. It works even if the
# editable-install metadata in pyproject.toml is incomplete.
sys.path.insert(0, str(PACKAGE_ROOT))
importlib.invalidate_caches()

# Remove any failed/stale import from memory
for module_name in list(sys.modules):
    if module_name == "market_mcp" or module_name.startswith("market_mcp."):
        del sys.modules[module_name]

# Optional editable installation
metadata_exists = any(
    (PACKAGE_ROOT / filename).exists()
    for filename in ("pyproject.toml", "setup.py", "setup.cfg")
)

if metadata_exists:
    result = subprocess.run(
        [
            sys.executable,
            "-m",
            "pip",
            "install",
            "-e",
            str(PACKAGE_ROOT),
            "--no-deps",
        ],
        capture_output=True,
        text=True,
    )

    print("\nEditable-install return code:", result.returncode)

    if result.returncode != 0:
        print(result.stderr)
        print("Continuing with direct sys.path loading.")

# ------------------------------------------------------------
# 4. Import and verify
# ------------------------------------------------------------

import market_mcp

from market_mcp.core import (
    UNIVERSE,
    SimulatedProvider,
    GovernanceEngine,
    VaultStore,
)

from market_mcp.orchestrator import MarketDayOrchestrator

print("\n✅ market_mcp imported successfully")
print("Module loaded from:", market_mcp.__file__)
print("Approved universe:", UNIVERSE)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Searching under: /content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER
#
# ZIP files detected:
#  - /content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom.zip
# Inspecting/extracting: Governed_Market_Memory_MCP_Classroom.zip
#
# ✅ Python package found
# Package directory: /content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom/market_mcp
# Package root: /content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom
#
# Editable-install return code: 0
#
# ✅ market_mcp imported successfully
# Module loaded from: /content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom/market_mcp/__init__.py
# Approved universe: {'^GSPC': 'S&P 500', '^DJI': 'Dow Jones Industrial Average', '^IXIC': 'Nasdaq Composite', '^FTSE': 'FTSE 100', '^N225': 'Nikkei 225'}

# %% [markdown]
# ## Source and limitation register
#
# `SimulatedProvider` generates five deterministic pedagogical states. The optional `YFinanceProvider` is an unofficial Yahoo-facing adapter, may be delayed or rate-limited, and is not an OpenAI or official Yahoo connector.

# %%
provider = SimulatedProvider()
metadata = {
    'provider': provider.name,
    'classification': 'SIMULATED',
    'official_yahoo_connector': False,
    'purpose': 'compressed classroom market day'
}
metadata
# Out:
# {'provider': 'governed-classroom-scenario',
#  'classification': 'SIMULATED',
#  'official_yahoo_connector': False,
#  'purpose': 'compressed classroom market day'}

# %% [markdown]
# ## Gate 1 — authorization failure is visible
#
# We first prove that the write boundary rejects an incorrect token. A governed system must demonstrate refusal, not merely successful execution.

# %%
engine = GovernanceEngine()
candidate = provider.snapshot(1)
rejected = engine.evaluate(candidate, 'WRONG-TOKEN', predecessor_count=0, cycle=1)
assert rejected['accepted'] is False
rejected
# Out:
# {'accepted': False,
#  'gates': {'authorization': False,
#   'universe': True,
#   'provenance': True,
#   'freshness': True,
#   'classification': True,
#   'completeness': True,
#   'memory': True,
#   'consistency': True},
#  'cycle': 1,
#  'evaluated_at': '2026-07-22T14:13:44.691370+00:00'}

# %% [markdown]
# ## Inspect the candidate observation
#
# Each row carries symbol, human-readable name, level, change, UTC timestamp, classification and provider. No interpretation is stored inside the observation record.

# %%
from dataclasses import asdict
import pandas as pd
pd.DataFrame([asdict(x) for x in candidate])
# Out:
#   symbol                          name     value  change_pct  \
# 0  ^GSPC                       S&P 500   6277.95       -0.35
# 1   ^DJI  Dow Jones Industrial Average  44874.00       -0.28
# 2  ^IXIC              Nasdaq Composite  20890.80       -0.52
# 3  ^FTSE                      FTSE 100   8983.80       -0.18
# 4  ^N225                    Nikkei 225  41325.70       -0.42
#
#                         observed_at classification  \
# 0  2026-07-22T14:13:44.691254+00:00      SIMULATED
# 1  2026-07-22T14:13:44.691254+00:00      SIMULATED
# 2  2026-07-22T14:13:44.691254+00:00      SIMULATED
# 3  2026-07-22T14:13:44.691254+00:00      SIMULATED
# 4  2026-07-22T14:13:44.691254+00:00      SIMULATED
#
#                       provider
# 0  governed-classroom-scenario
# 1  governed-classroom-scenario
# 2  governed-classroom-scenario
# 3  governed-classroom-scenario
# 4  governed-classroom-scenario

# %% [markdown]
# ## Run cycle 1
#
# The first report correctly records that no predecessor exists. It therefore establishes the initial state without fabricating memory.

# %%
store = VaultStore(VAULT)
decision1 = engine.evaluate(candidate, 'CLASSROOM-AUTHORIZED', len(store.previous_reports()), 1)
report1 = store.save_cycle(1, candidate, decision1)
print(report1.read_text())
# Out:
# ---
# cycle: 1
# classification: SIMULATED
# provider: governed-classroom-scenario
# governance_status: ACCEPTED
# ---
# # Minute 1 — Governed Market Report
#
# ## Memory consulted
# None — first observation
#
# ## Observations
# | Index | Level | Change | Classification |
# |---|---:|---:|---|
# | S&P 500 | 6,277.95 | -0.35% | SIMULATED |
# | Dow Jones Industrial Average | 44,874.00 | -0.28% | SIMULATED |
# | Nasdaq Composite | 20,890.80 | -0.52% | SIMULATED |
# | FTSE 100 | 8,983.80 | -0.18% | SIMULATED |
# | Nikkei 225 | 41,325.70 | -0.42% | SIMULATED |
#
# ## Derived state
# Cross-index average: **-0.35%**. Dispersion: **0.34 percentage points**.
#
# ## Interpretation
# Relative to the available path, this cycle represents **deterioration or opening state**. This sentence is interpretation, not an observed market fact.
#
# ## Governance evidence
# All required gates passed. Decision record: `04_Audit/cycle_01_decision.json`.

# %% [markdown]
# ## Run cycles 2–5 with predecessor retrieval
#
# Before each write, the gate requires exactly `cycle − 1` reports. Each Markdown report lists the Obsidian links it consulted.

# %%
cycle_evidence = []
for cycle in range(2, 6):
    observations = provider.snapshot(cycle)
    predecessors = store.previous_reports()
    decision = engine.evaluate(observations, 'CLASSROOM-AUTHORIZED', len(predecessors), cycle)
    path = store.save_cycle(cycle, observations, decision)
    cycle_evidence.append({'cycle': cycle, 'predecessors': [p.stem for p in predecessors], 'accepted': decision['accepted'], 'report': path.name})
pd.DataFrame(cycle_evidence)
# Out:
#    cycle                                  predecessors  accepted        report
# 0      2                                   [Minute_01]      True  Minute_02.md
# 1      3                        [Minute_01, Minute_02]      True  Minute_03.md
# 2      4             [Minute_01, Minute_02, Minute_03]      True  Minute_04.md
# 3      5  [Minute_01, Minute_02, Minute_03, Minute_04]      True  Minute_05.md

# %% [markdown]
# ## Path-dependent synthesis
#
# The final narrative uses the complete accepted chain. Its central claim is not merely the closing direction, but the intraday transition from broad stress to selective risk appetite and geographic/style divergence.

# %%
final_path = store.finalize()
print(final_path.read_text())
# Out:
# # End-of-Day Narrative — Compressed Classroom Session
#
# Classification: **SIMULATED classroom scenario**.
#
# The path began with a broad opening shock, deepened into synchronized selling, then reversed. The rebound was uneven: US technology leadership pulled the Nasdaq and S&P 500 into positive territory while the Dow lagged and European and Asian benchmarks remained negative. The close therefore cannot be described simply as “markets rose.” The more faithful account is a transition from contagion risk to selective risk appetite, with widening geographic and style divergence.
#
# ## Lineage
# - [[Minute_01]]
# - [[Minute_02]]
# - [[Minute_03]]
# - [[Minute_04]]
# - [[Minute_05]]

# %% [markdown]
# ## Audit manifest and cryptographic integrity
#
# The manifest records every artifact path, byte count and SHA-256 digest. Recalculation turns a vague promise of traceability into an executable test.

# %%
manifest_path = store.manifest()
verification = store.verify()
assert verification['valid']
verification
# Out:
# {'valid': True, 'failures': [], 'file_count': 13}

# %% [markdown]
# ## Validate semantics and lineage
#
# These tests fail visibly if the first report invents a predecessor, the fifth report omits the fourth, any classification disappears, or fewer than five accepted reports exist.

# %%
reports = store.previous_reports()
assert len(reports) == 5
assert 'None — first observation' in reports[0].read_text()
assert '[[Minute_04]]' in reports[4].read_text()
assert all('classification: SIMULATED' in p.read_text() for p in reports)
assert (VAULT / '04_Audit/events.jsonl').exists()
print('All semantic, lineage, classification and audit checks passed.')
# Out:
# All semantic, lineage, classification and audit checks passed.

# %% [markdown]
# ## MCP tool surface
#
# `market_mcp.server` exposes read tools for universe, snapshots, status, metadata, validation and prior reports; controlled write tools create reports, finalize the narrative, generate the manifest and verify integrity.
#
# Start locally with `python -m market_mcp.server`. A remote deployment needs HTTPS and appropriate authentication. MCP waits for calls; it does not schedule itself.

# %%
# Display the governed tool names from source without starting a blocking server.
tool_names = [
 'get_market_universe', 'get_market_snapshot', 'get_market_status',
 'get_provider_metadata', 'validate_snapshot', 'read_previous_reports',
 'save_snapshot', 'save_report', 'finalize_market_day',
 'write_audit_manifest', 'verify_vault_integrity'
]
tool_names
# Out:
# ['get_market_universe',
#  'get_market_snapshot',
#  'get_market_status',
#  'get_provider_metadata',
#  'validate_snapshot',
#  'read_previous_reports',
#  'save_snapshot',
#  'save_report',
#  'finalize_market_day',
#  'write_audit_manifest',
#  'verify_vault_integrity']

# %% [markdown]
# ## Optional five-real-minute execution
#
# For a live classroom performance, start with a fresh vault and run the orchestrator with `interval_seconds=60`. Do not rerun against the completed vault because the memory gate will correctly reject duplicate sequencing.

# %%
#Uncomment only for a fresh five-minute classroom performance.
fresh_vault = PACKAGE_ROOT / 'Five_Real_Minute_Run'
result = MarketDayOrchestrator(fresh_vault).run(cycles=5, interval_seconds=60)
result['verification']
# Out:
# {'valid': True, 'failures': [], 'file_count': 13}

# %% [markdown]
# ## Export the audit bundle
#
# The ZIP is a portable evidence package. The working vault remains ordinary Markdown/CSV/JSON and can be opened directly in Obsidian.

# %%
import shutil
zip_path = shutil.make_archive(str(PACKAGE_ROOT / 'Market_Day_Audit_Bundle'), 'zip', VAULT)
print(zip_path)
# Out:
# /content/drive/MyDrive/THE ESSENTIAL AUTONOMOUS WORKFLOWS/THE FINANCIAL REPORTER/Governed_Market_Memory_MCP_Classroom/Market_Day_Audit_Bundle.zip

# %% [markdown]
# ## Production extension
#
# Replace the simulated provider with a licensed adapter; replace Colab with a persistent scheduler; implement market calendars, explicit freshness thresholds, OAuth 2.1, secrets management, durable telemetry, retries, retention and human review. Keep reporting isolated from trading authority.
#
# Official OpenAI references:
#
# - https://developers.openai.com/apps-sdk/build/mcp-server
# - https://developers.openai.com/apps-sdk/concepts/mcp-server
# - https://developers.openai.com/api/docs/guides/tools-connectors-mcp
# - https://developers.openai.com/apps-sdk/build/auth
